# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

jump10 = []
with open('all_int_trans_200_0.txt', 'r') as inp1:
    for line in inp1:
        arr = line.split()
        a = float(arr[1])
        if a >= 10.0:
            jump10.append(a)
            
jump20 = []
with open('all_int_trans_400_0.txt', 'r') as inp2:
    for line2 in inp2:
        arr2 = line2.split()
        a2 = float(arr2[1])
        if a2 >= 10.0:
            jump20.append(a2)
            
jump30 = []
with open('all_int_trans_600_0.txt', 'r') as inp3:
    for line3 in inp3:
        arr3 = line3.split()
        a3 = float(arr3[1])
        if a3 >= 10.0:
            jump30.append(a3)
            
jump40 = []
with open('all_int_trans_800_0.txt', 'r') as inp4:
    for line4 in inp4:
        arr4 = line4.split()
        a4 = float(arr4[1])
        if a4 >= 10.0:
            jump40.append(a4)
            
jump50 = []
with open('all_int_trans_1000_7.txt', 'r') as inp5:
    for line5 in inp5:
        arr5 = line5.split()
        a5 = float(arr5[1])
        if a5 >= 10.0:
            jump50.append(a5)

data10 = np.array(jump10)
data20 = np.array(jump20)
data30 = np.array(jump30)
data40 = np.array(jump40)
data50 = np.array(jump50)


#data = [data1m, data2m, data3m, data4m, data5m]    
data0 = [data10, data20, data30, data40, data50]
cmap = sns.color_palette("rainbow")
fig, ax = plt.subplots()
#x_labels = ['222$\AA$', '420$\AA$', '620$\AA$', '812$\AA$', '994$\AA$']
cmap = sns.color_palette("rainbow")
sns.violinplot(data=data0, ax=ax, width=1.1, palette=cmap, split=True, scale="width")
ax.set_ylim(-5,100)
ax.set_xticklabels(['222$\AA$', '420$\AA$', '620$\AA$', '812$\AA$', '994$\AA$'], fontsize=16)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
plt.xlabel("End-to-end distances", fontsize=20)
plt.ylabel("Size of Intersegmental \n Transfers (Δnt)", fontsize=20)
plt.savefig('highsalt_violin.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1305326/2859943907.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

jump1 = []
with open('all_int_trans_200_7.txt', 'r') as inp1:
    for line in inp1:
        arr = line.split()
        a = float(arr[1])
        if a >= 10.0:
            jump1.append(a)
            
jump2 = []
with open('all_int_trans_400_7.txt', 'r') as inp2:
    for line2 in inp2:
        arr2 = line2.split()
        a2 = float(arr2[1])
        if a2 >= 10.0:
            jump2.append(a2)
            
jump3 = []
with open('all_int_trans_600_7.txt', 'r') as inp3:
    for line3 in inp3:
        arr3 = line3.split()
        a3 = float(arr3[1])
        if a3 >= 10.0:
            jump3.append(a3)
            
jump4 = []
with open('all_int_trans_800_7.txt', 'r') as inp4:
    for line4 in inp4:
        arr4 = line4.split()
        a4 = float(arr4[1])
        if a4 >= 10.0:
            jump4.append(a4)
            
jump5 = []
with open('all_int_trans_1000_7.txt', 'r') as inp5:
    for line5 in inp5:
        arr5 = line5.split()
        a5 = float(arr5[1])
        if a5 >= 10.0:
            jump5.append(a5)

data1 = np.array(jump1)
data2 = np.array(jump2)
data3 = np.array(jump3)
data4 = np.array(jump4)
data5 = np.array(jump5)


#data = [data1m, data2m, data3m, data4m, data5m]    
data = [data1, data2, data3, data4, data5]
cmap = sns.color_palette("rainbow")
fig, ax = plt.subplots()
#x_labels = ['222$\AA$', '420$\AA$', '620$\AA$', '812$\AA$', '994$\AA$']
cmap = sns.color_palette("rainbow")
sns.violinplot(data=data, ax=ax, width=1.1, palette=cmap, split=True, scale="width")
ax.set_ylim(-5,200)
ax.set_xticklabels(['222$\AA$', '420$\AA$', '620$\AA$', '812$\AA$', '994$\AA$'], fontsize=16)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
plt.xlabel("End-to-end distances", fontsize=20)
plt.ylabel("Size of Intersegmental \n Transfers (Δnt)", fontsize=20)
plt.savefig('lowsalt_violin.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1305326/2543517493.py:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)

# %%
fig, ax = plt.subplots()
cmap = sns.color_palette("rainbow")
sns.violinplot(data=data, ax=ax, positions=[0,2,4,6,8], width=1.0, palette=cmap, split=True)
sns.violinplot(data=data0, ax=ax, positions=[1,3,5,7,9], width=1.0, palette=cmap, split=True)
ax.set_xticks([0.3,1.3,2.3,3.3,4.3])
ax.set_xticklabels(['200', '400', '600', '800', '1000'])
ax.set_xlabel('Time (ms)')
ax.set_ylabel('Jump Size')
ax.legend(['Data', 'Data0'])
plt.show()

# %%
fig, ax = plt.subplots()
cmap = sns.color_palette("rainbow")
width = 0.35
x_ticks = np.array([0, 1, 2, 3, 4])
ax.set_xticks(x_ticks)
ax.set_xticklabels(['200', '400', '600', '800', '1000'])
ax.set_xlabel('Time (ms)')
ax.set_ylabel('Jump Size')

# plot the first set of violins
pos1 = np.arange(len(data)) * 2 - width/2
sns.violinplot(data=data, ax=ax, positions=pos1, width=width, palette=cmap, scale="width")

# plot the second set of violins
pos2 = np.arange(len(data0)) * 2 + width/2
sns.violinplot(data=data0, ax=ax, positions=pos2, width=width, palette=cmap, scale="width")

# add legend
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['Data', 'Data0'])
plt.show()

# %%
fig, ax = plt.subplots()
cmap = sns.color_palette("rainbow")
positions = [0.2, 0.6, 1.2, 1.6, 2.2, 2.6, 3.2, 3.6, 4.2, 4.6]
sns.violinplot(data=data, ax=ax, positions=positions[::2], width=0.9, palette=cmap, scale="width")
sns.violinplot(data=data0, ax=ax, positions=positions[1::2], width=0.9, palette=cmap, scale="width")
ax.set_xticks([0.4, 1.4, 2.4, 3.4, 4.4])
ax.set_xticklabels(['200', '400', '600', '800', '1000'])
ax.set_xlabel('Time (ms)')
ax.set_ylabel('Jump Size')
ax.legend(['Data', 'Data0'])
plt.show()
plt.ylim(0,200)
# Out:
# (0.0, 200.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde
import seaborn as sns

dmod1 = np.loadtxt('all_int_trans_200_7.txt')
dmod2 = np.loadtxt('all_int_trans_400_7.txt')
dmod3 = np.loadtxt('all_int_trans_600_7.txt')
dmod4 = np.loadtxt('all_int_trans_800_7.txt')
dmod5 = np.loadtxt('all_int_trans_1000_7.txt')

dmop1 = np.loadtxt('all_int_trans_200_0.txt')
dmop2 = np.loadtxt('all_int_trans_400_0.txt')
dmop3 = np.loadtxt('all_int_trans_600_0.txt')
dmop4 = np.loadtxt('all_int_trans_800_0.txt')
dmop5 = np.loadtxt('all_int_trans_1000_0.txt')

jump1 = dmod1[:,1]
jump2 = dmod2[:,1]
jump3 = dmod3[:,1]
jump4 = dmod4[:,1]
jump5 = dmod5[:,1]

jump10 = dmop1[:,1]
jump20 = dmop2[:,1]
jump30 = dmop3[:,1]
jump40 = dmop4[:,1]
jump50 = dmop5[:,1]

data1m = jump1/7.0
data2m = jump2/9.0
data3m = jump3/7.0
data4m = jump4/10.0
data5m = jump5/10.0
data = [data1m, data2m, data3m, data4m, data5m]    

data10m = jump10/10.0
data20m = jump20/10.0
data30m = jump30/10.0
data40m = jump40/10.0
data50m = jump50/10.0
data0 = [data10m, data20m, data30m, data40m, data50m]
fig, ax = plt.subplots()
cmap = sns.color_palette("rainbow")
#sns.violinplot(data=data, ax=ax, width=1.1, palette=cmap, split=True, scale="width")
sns.violinplot(data=data, ax=ax, width=1.1, palette=cmap, split=True, scale="width")
ax.set_ylim(-10,100)
ax.set_xticklabels(['222$\AA$', '420$\AA$', '620$\AA$', '812$\AA$', '994$\AA$'], fontsize=16)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
plt.xlabel("End-to-end distances", fontsize=20)
plt.ylabel("Size of Intersegmental \n Transfers (ΔNT)", fontsize=20)
#plt.savefig('lowsalt_violin.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1305326/4017474601.py:49: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# Text(0, 0.5, 'Size of Intersegmental \n Transfers (ΔNT)')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde
import seaborn as sns

jump1 = []
with open('all_int_trans_200_7.txt', 'r') as inp1:
    for line in inp1:
        arr = line.split()
        a = float(arr[1])
        if a >= 10.0:
            jump1.append(a)
            
jump2 = []
with open('all_int_trans_400_7.txt', 'r') as inp2:
    for line2 in inp2:
        arr2 = line2.split()
        a2 = float(arr2[1])
        if a2 >= 10.0:
            jump2.append(a2)
            
jump3 = []
with open('all_int_trans_600_7.txt', 'r') as inp3:
    for line3 in inp3:
        arr3 = line3.split()
        a3 = float(arr3[1])
        if a3 >= 10.0:
            jump3.append(a3)
            
jump4 = []
with open('all_int_trans_800_7.txt', 'r') as inp4:
    for line4 in inp4:
        arr4 = line4.split()
        a4 = float(arr4[1])
        if a4 >= 10.0:
            jump4.append(a4)
            
jump5 = []
with open('all_int_trans_1000_7.txt', 'r') as inp5:
    for line5 in inp5:
        arr5 = line5.split()
        a5 = float(arr5[1])
        if a5 >= 10.0:
            jump5.append(a5)
            
data1 = np.array(jump1)
data2 = np.array(jump2)
data3 = np.array(jump3)
data4 = np.array(jump4)
data5 = np.array(jump5)

data1m = data1/7.0
data2m = data2/9.0
data3m = data3/7.0
data4m = data4/10.0
data5m = data5/10.0
data = [data1, data2, data3, data4, data5]   
cmap = sns.color_palette("rainbow")
#sns.violinplot(data=data, ax=ax, width=1.1, palette=cmap, split=True, scale="width")
sns.violinplot(data=data, ax=ax, width=1.1, palette=cmap, split=True, scale="width")
ax.set_ylim(-10,100)
ax.set_xticklabels(['222$\AA$', '420$\AA$', '620$\AA$', '812$\AA$', '994$\AA$'], fontsize=16)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
plt.xlabel("End-to-end distances", fontsize=20)
plt.ylabel("Size of Intersegmental \n Transfers (ΔNT)", fontsize=20)
#plt.savefig('lowsalt_violin.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1305326/1206337724.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# Text(0, 0.5, 'Size of Intersegmental \n Transfers (ΔNT)')
