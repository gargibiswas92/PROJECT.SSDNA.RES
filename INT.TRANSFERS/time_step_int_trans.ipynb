# %%
import numpy as np
import matplotlib.pyplot as plt

d1 = np.loadtxt('all_int_trans_200_0.txt')
d2 = np.loadtxt('all_int_trans_400_0.txt')
d3 = np.loadtxt('all_int_trans_600_0.txt')
d4 = np.loadtxt('all_int_trans_800_0.txt')
d5 = np.loadtxt('all_int_trans_1000_0.txt')

time1 = d1[:,0]
time2 = d2[:,0]
time3 = d3[:,0]
time4 = d4[:,0]
time5 = d5[:,0]

jump1 = d1[:,1]
jump2 = d2[:,1]
jump3 = d3[:,1]
jump4 = d4[:,1]
jump5 = d5[:,1]

x1 = len(jump1) // 49998
x2 = len(jump2) // 49998
x3 = len(jump3) // 49998
x4 = len(jump4) // 49998
x5 = len(jump5) // 49998

jump1_ind = np.array_split(jump1, x1)
time1_ind = np.array_split(time1, x1)

jump2_ind = np.array_split(jump2, x2)
time2_ind = np.array_split(time2, x2)

jump3_ind = np.array_split(jump3, x3)
time3_ind = np.array_split(time3, x3)

jump4_ind = np.array_split(jump4, x1)
time4_ind = np.array_split(time4, x1)

jump5_ind = np.array_split(jump5, x1)
time5_ind = np.array_split(time5, x1)

fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(20,5))

for k1 in range(x1):
    name = 'simulation '+str(k1+1)
    ax[0].plot(time1_ind[k1], jump1_ind[k1], label = name)
    #ax[0].legend()
ax[0].set_xlabel('MD Time steps (x 1000)', fontsize=18)
ax[0].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[0].set_ylim(-2,165)

for k2 in range(x2):
    name = 'simulation '+str(k2+1)
    ax[1].plot(time2_ind[k2], jump2_ind[k2], label = name)
    #ax[1].legend()
ax[1].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[1].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[1].set_ylim(-2,165)

for k3 in range(x3):
    name = 'simulation '+str(k3+1)
    ax[2].plot(time3_ind[k3], jump3_ind[k3], label = name)
    #ax[2].legend()
ax[2].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[2].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[2].set_ylim(-2,165)

for k4 in range(x4):
    name = 'simulation '+str(k4+1)
    ax[3].plot(time4_ind[k1], jump4_ind[k1], label = name)
    #ax[3].legend()
ax[3].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[3].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[3].set_ylim(-2,165)

for k5 in range(x5):
    name = 'simulation '+str(k5+1)
    ax[4].plot(time5_ind[k5], jump5_ind[k5], label = name)
    #ax[4].legend()
ax[4].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[4].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=20)
ax[4].set_ylim(-2,165)

plt.savefig('int_trans_time_high_salt.png', dpi=300, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

d1 = np.loadtxt('all_int_trans_200_7.txt')
d2 = np.loadtxt('all_int_trans_400_7.txt')
d3 = np.loadtxt('all_int_trans_600_7.txt')
d4 = np.loadtxt('all_int_trans_800_7.txt')
d5 = np.loadtxt('all_int_trans_1000_7.txt')

time1 = d1[:,0]
time2 = d2[:,0]
time3 = d3[:,0]
time4 = d4[:,0]
time5 = d5[:,0]

jump1 = d1[:,1]
jump2 = d2[:,1]
jump3 = d3[:,1]
jump4 = d4[:,1]
jump5 = d5[:,1]

x1 = len(jump1) // 49998
x2 = len(jump2) // 49998
x3 = len(jump3) // 49998
x4 = len(jump4) // 49998
x5 = len(jump5) // 49998

jump1_ind = np.array_split(jump1, x1)
time1_ind = np.array_split(time1, x1)

jump2_ind = np.array_split(jump2, x2)
time2_ind = np.array_split(time2, x2)

jump3_ind = np.array_split(jump3, x3)
time3_ind = np.array_split(time3, x3)

jump4_ind = np.array_split(jump4, x4)
time4_ind = np.array_split(time4, x4)

jump5_ind = np.array_split(jump5, x5)
time5_ind = np.array_split(time5, x5)

fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(20,5))

for k1 in range(x1):
    name = 'simulation '+str(k1+1)
    ax[0].plot(time1_ind[k1], jump1_ind[k1], label = name)
    #ax[0].legend()
ax[0].set_xlabel('MD Time steps (x 1000)', fontsize=18)
ax[0].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[0].set_ylim(-2,205)

for k2 in range(x2):
    name = 'simulation '+str(k2+1)
    ax[1].plot(time2_ind[k2], jump2_ind[k2], label = name)
    #ax[1].legend()
ax[1].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[1].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[1].set_ylim(-2,205)

for k3 in range(x3):
    name = 'simulation '+str(k3+1)
    ax[2].plot(time3_ind[k3], jump3_ind[k3], label = name)
    #ax[2].legend()
ax[2].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[2].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[2].set_ylim(-2,205)

for k4 in range(x4):
    name = 'simulation '+str(k4+1)
    ax[3].plot(time4_ind[k4], jump4_ind[k4], label = name)
    #ax[3].legend()
ax[3].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[3].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=10)
ax[3].set_ylim(-2,205)

for k5 in range(x5):
    name = 'simulation '+str(k5+1)
    ax[4].plot(time5_ind[k5], jump5_ind[k5], label = name)
    #ax[4].legend()
ax[4].set_xlabel('MD Time steps (x 1000)', fontsize=18)
#ax[4].set_ylabel('Jump Size (nt)', fontsize=18, labelpad=20)
ax[4].set_ylim(-2,205)

plt.savefig('int_trans_time_low_salt.png', dpi=300, bbox_inches='tight')
