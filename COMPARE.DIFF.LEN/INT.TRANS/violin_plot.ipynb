# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde
import seaborn as sns

jump1 = []
with open('all_int_trans_200.txt', 'r') as inp1:
    for line in inp1:
        arr = line.split()
        a = float(arr[1])
        if a >= 10.0:
            jump1.append(a)
            
jump2 = []
with open('all_int_trans_460.txt', 'r') as inp2:
    for line2 in inp2:
        arr2 = line2.split()
        a2 = float(arr2[1])
        if a2 >= 10.0:
            jump2.append(a2)
            
jump3 = []
with open('all_int_trans_860.txt', 'r') as inp3:
    for line3 in inp3:
        arr3 = line3.split()
        a3 = float(arr3[1])
        if a3 >= 10.0:
            jump3.append(a3)
            
jump4 = []
with open('all_int_trans_1400.txt', 'r') as inp4:
    for line4 in inp4:
        arr4 = line4.split()
        a4 = float(arr4[1])
        if a4 >= 10.0:
            jump4.append(a4)
data1 = np.array(jump1)
data2 = np.array(jump2)
data3 = np.array(jump3)
data4 = np.array(jump4)
   
data = [data1, data2, data3, data4]
#cmap = sns.color_palette("rainbow")
fig, ax = plt.subplots()
#x_labels = ['222$\AA$', '420$\AA$', '620$\AA$', '812$\AA$', '994$\AA$']
cmap = sns.color_palette("Set2")
sns.violinplot(data=data, ax=ax, width=1.1, palette=cmap, split=True, scale="width")
#ax.set_ylim(-5,100)
ax.set_xticklabels(['235', '460', '860', '1400'], fontsize=16)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
plt.xlabel("Length of DNA (nt)", fontsize=20)
plt.ylabel("Size of Intersegmental \n Transfers (Δnt)", fontsize=20)
plt.savefig('diffdis_violin.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_1340356/3907339398.py:50: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
